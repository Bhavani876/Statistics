# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from scipy.stats import skew
from scipy.stats import kurtosis
import statistics as st
import warnings
warnings.filterwarnings('ignore')

# %%
data=pd.read_csv("DS1_C5_S3_GamesSales_Data_Challenge.csv")

# %%
data
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...

# %%
df.shape
# Out:
# (709, 9)

# %%
df.columns
# Out:
# Index(['Game', 'Year', 'Genre', 'Publisher', 'North_America_Sales_M$',
#        'Europe_Sales_M$', 'Japan_Sales_M$', 'Other_Sales_M$',
#        'Global_Sales_M$'],
#       dtype='object')

# %% [markdown]
# # task 1

# %%
#labour force of female=.46
#part-time of female=.25
#American labour=.17.4
t1=(46/100)*(25/100)

# %%
t1
# Out:
# 0.115

# %%
T1=(11.5/17.4)*100
round(T1,2)
# Out:
# 66.09

# %% [markdown]
# # task2

# %%
#Reduce Noise=.70
#Storage Space=67
#Noise and Storage=.56

# %%
#p(Noise)=.70
#p(Storage)=.67
#p(Storage and Noise)=.56
t2=((67/100) - (56/100))
round(t2,2)
# Out:
# 0.11

# %% [markdown]
# # task 3

# %% [markdown]
# # subtask 3.1.1 without replacement

# %%
data.sample(30,replace=False).sort_index()
# Out:
#                                                   Game  Year  \
# 44                         The Elder Scrolls V: Skyrim  2018
# 47                        Resident Evil VII: Biohazard  2019
# 90                      Kingdom Hearts 1.5 + 2.5 Remix  2019
# 101                                           NBA 2K14  2015
# 126                                LEGO Jurassic World  2017
# 134                                   Alien: Isolation  2016
# 174                                     Sniper Elite 3  2016
# 179                        Marvel vs. Capcom: Infinite  2019
# 186                  Plants vs Zombies: Garden Warfare  2016
# 194                                            F1 2019  2019
# 242                                         Dishonored  2017
# 252                                 Resident Evil Zero  2018
# 266                                Valkyria Chronicles  2018
# 289                                     Secret of Mana  2020
# ...

# %% [markdown]
# # 3.1.2  with replacement

# %%
data.sample(30,replace=True).sort_index()
# Out:
#                                                   Game  Year  \
# 62                                       Madden NFL 18  2019
# 80                         Middle-Earth: Shadow of War  2019
# 83                                        Just Cause 3  2017
# 104                                     Rayman Legends  2016
# 123       Kingdom Hearts HD 2.8 Final Chapter Prologue  2019
# 179                        Marvel vs. Capcom: Infinite  2019
# 195                                             NHL 15  2016
# 254                                             Vampyr  2020
# 260                                    Dead or Alive 5  2017
# 337                                    Godzilla (2015)  2016
# 353                      Final Fantasy XIV: Stormblood  2019
# 369                   Psycho-Pass: Mandatory Happiness  2018
# 411                        Samurai Warriors 4: Empires  2017
# 418                 Minecraft: Story Mode - Season Two  2019
# ...

# %% [markdown]
# # 3.1.3 systematic sampling

# %%
data[::30]
# Out:
#                                            Game  Year             Genre  \
# 0                            Grand Theft Auto V  2016            Action
# 30                         Call of Duty: Ghosts  2015           Shooter
# 60                              Far Cry: Primal  2018  Action-Adventure
# 90               Kingdom Hearts 1.5 + 2.5 Remix  2019      Role-Playing
# 120             Metal Gear Solid: Ground Zeroes  2016  Action-Adventure
# 150             Ni no Kuni II: Revenant Kingdom  2020      Role-Playing
# 180                               Dark Souls II  2017      Role-Playing
# 210                         Lords of the Fallen  2016      Role-Playing
# 240                               Trials Fusion  2016              Misc
# 270                          DmC: Devil May Cry  2017            Action
# 300                              Darksiders III  2020            Action
# 330           Senran Kagura: Peach Beach Splash  2019            Action
# ...

# %% [markdown]
# # 3.1.4 stratified sampling  for year

# %%
year_grp=data.groupby(['Year'])
year_data=df['Year'].unique()
str_data=pd.DataFrame()
for i in year_data:
    year_d=year_grp.get_group(i)
    sam_year=year_d.sample(3)
    str_data=str_data.append(sam_year)
str_data
# Out:
#                                                   Game  Year         Genre  \
# 299                                 Samurai Warriors 4  2016      Fighting
# 274                 Dynasty Warriors 8: Xtreme Legends  2016          Misc
# 71                                       Madden NFL 15  2016        Sports
# 457                             God Eater Resurrection  2017        Action
# 163  Dragon Quest Heroes: The World's Tree Woe and ...  2017        Action
# 226                         Wolfenstein: The Old Blood  2017       Shooter
# 106                              Dragon Ball Fighter Z  2020      Fighting
# 592                                    Darkest Dungeon  2020  Role-Playing
# 572                                  Pure Farming 2020  2020    Simulation
# 207                                           DOOM VFR  2019       Shooter
# 630                                              AereA  2019  Role-Playing
# ...

# %% [markdown]
# # 3.1.4 stratified sampling  for Genre

# %%
Genre_grp=data.groupby(['Genre'])
Genre_data=data['Genre'].unique()
str_df=pd.DataFrame()
for i in Genre_data:
    Genre_d=Genre_grp.get_group(i)
    sam_Genre=Genre_d.sample(2)
    str_data=str_data.append(sam_Genre)
str_data
# Out:
#                                     Game  Year         Genre  \
# 674                            White Day  2019        Action
# 505                               ZombiU  2018        Action
# 64                           Dying Light  2017        Action
# 697                Gal Gun: Double Peace  2017        Action
# 464  Lara Croft and the Temple of Osiris  2016        Action
# ..                                   ...   ...           ...
# 686              Battle Garegga Rev.2018  2018      Strategy
# 569                  The Talos Principle  2017        Puzzle
# 660  The Inner World: The Last Wind Monk  2019        Puzzle
# 669                          Chaos;Child  2017  Visual Novel
# 693          Chaos;Child: Love Chu Chu!!  2019  Visual Novel
#
#                     Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 674                     PQube                    0.00             0.01
# 505                   Ubisoft                    0.00             0.04
# ...

# %% [markdown]
# # 3.1.5 Clustered sampling

# %%
year_grp=data.groupby(['Year'])
year_data=[2015,2018,2020]
clus_data=pd.DataFrame()
for i in year_data:
    year_d=year_grp.get_group(i)
    sam_year=year_d.sample(frac=.20)
    clus_data=clus_data.append(sam_year)
clus_data
# Out:
#                                                   Game  Year  \
# 55                               Killzone: Shadow Fall  2015
# 146                                      Madden NFL 25  2015
# 51                     Assassin's Creed IV: Black Flag  2015
# 557  Tokyo Twilight Ghost Hunters Daybreak: Special...  2018
# 262                           Odin Sphere: Leifthrasir  2018
# 613                                       Koihime Enbu  2018
# 483                                    Project Setsuna  2018
# 688                      Farming 2017 - The Simulation  2018
# 645  God Eater Off Shot: Tachibana Sakuya-hen Twin ...  2018
# 109                                   Street Fighter V  2018
# 475                                        Dead Rising  2018
# 545                                  Werewolves Within  2018
# 159                               Farming Simulator 17  2018
# 665                             Skullgirls: 2nd Encore  2018
# ...

# %%
Genre_grp=data.groupby(['Genre'])
Genre_data=['Action','Puzzle']
clus_data=pd.DataFrame()
for i in Genre_data:
    Genre_d=Genre_grp.get_group(i)
    sam_Genre=Genre_d.sample(frac=.20)
    clus_data=clus_data.append(sam_Genre)
clus_data
# Out:
#                                                   Game  Year   Genre  \
# 343                                    Toukiden Kiwami  2017  Action
# 253                                    Yakuza Kiwami 2  2019  Action
# 40                          Assassin's Creed Syndicate  2017  Action
# 385         Adventure Time: Finn & Jake Investigations  2017  Action
# 317                     RIGS: Mechanized Combat League  2018  Action
# 323                                  Attack on Titan 2  2020  Action
# 286    The Heavy Rain and Beyond: Two Souls Collection  2018  Action
# 449                                  Nights of Azure 2  2019  Action
# 653                            Carmageddon: Max Damage  2018  Action
# 328                                    Outlast Trinity  2019  Action
# 690                                     Zombie Vikings  2018  Action
# 580               Yonder: The Cloud Catcher Chronicles  2019  Action
# 339                                   Agents of Mayhem  2019  Action
# ...

# %%
s_10=data.sample(10)
s_10
# Out:
#                                               Game  Year             Genre  \
# 132                                  EA Sports UFC  2016          Fighting
# 609                                    Troll and I  2019            Action
# 417                                 Constructor HD  2019          Strategy
# 387                                   We Happy Few  2020  Action-Adventure
# 180                                  Dark Souls II  2017      Role-Playing
# 479                          God Wars: Future Past  2019      Role-Playing
# 678                                    Raven's Cry  2017      Role-Playing
# 113                                EA Sports UFC 2  2018            Sports
# 384                                  Shovel Knight  2017          Platform
# 283  Metal Gear Solid V: The Definitive Experience  2018            Action
#
#                         Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# ...

# %%
s_20=data.sample(20)
s_20
# Out:
#                                                   Game  Year  \
# 41                                            NBA 2K17  2018
# 437                                        Musou Stars  2019
# 137                                        Prey (2019)  2019
# 230                                            Knack 2  2019
# 193                             World of Final Fantasy  2018
# 25                                           Overwatch  2018
# 111                                           WWE 2K18  2019
# 317                     RIGS: Mechanized Combat League  2018
# 262                           Odin Sphere: Leifthrasir  2018
# 36                                            NBA 2K16  2017
# 457                             God Eater Resurrection  2017
# 159                               Farming Simulator 17  2018
# 518                          Nobunaga no Yabou: Souzou  2016
# 689  Re:Zero - Kara Hajimeru Isekai Seikatsu - Deat...  2019
# ...

# %%
s_30=data.sample(30)
s_30
# Out:
#                                                   Game  Year  \
# 689  Re:Zero - Kara Hajimeru Isekai Seikatsu - Deat...  2019
# 217                                         DiRT Rally  2018
# 639                                        Lost Sphear  2019
# 665                             Skullgirls: 2nd Encore  2018
# 586                 Aegis of Earth: Protonovus Assault  2018
# 437                                        Musou Stars  2019
# 664                       Genkai Tokki: Castle Panzers  2019
# 264                           The King of Fighters XIV  2018
# 271                                        Sonic Mania  2019
# 157                          Until Dawn: Rush of Blood  2018
# 634                                      Omega Quintet  2016
# 706                   Darius Burst: Chronicle Saviours  2019
# 486                            Styx: Shards of Darknes  2019
# 159                               Farming Simulator 17  2018
# ...

# %%
s_40=data.sample(40)
s_40
# Out:
#                                                   Game  Year  \
# 578                    Under Night In-Birth Exe:Latest  2019
# 137                                        Prey (2019)  2019
# 73                             Destiny: The Taken King  2017
# 428                                   Gundam Breaker 3  2018
# 242                                         Dishonored  2017
# 25                                           Overwatch  2018
# 702                           Deception IV: Blood Ties  2017
# 556                                Assault Suit Leynos  2018
# 139                                              Ni-Oh  2019
# 677          Summer Lesson: Miyamoto Hikari Collection  2019
# 371                                  Warriors Orochi 3  2016
# 251                                    Life is Strange  2018
# 637                                Rugby League Live 3  2017
# 552                           SŽbastien Loeb Rally Evo  2018
# ...

# %%
sb.histplot(s_10['Global_Sales_M$'],kde=True)
# Out:
# <AxesSubplot:xlabel='Global_Sales_M$', ylabel='Count'>

# %%
#s_10 has a right-skew.

# %%
sb.histplot(s_20['Global_Sales_M$'],kde=True)
# Out:
# <AxesSubplot:xlabel='Global_Sales_M$', ylabel='Count'>

# %%
#s_20 has a right-skew.

# %%
sb.histplot(s_30['Global_Sales_M$'],kde=True)
# Out:
# <AxesSubplot:xlabel='Global_Sales_M$', ylabel='Count'>

# %%
#s_30 has a right-skew.

# %%
sb.histplot(s_40['Global_Sales_M$'],kde=True)
# Out:
# <AxesSubplot:xlabel='Global_Sales_M$', ylabel='Count'>

# %%
sb.histplot(data['Global_Sales_M$'],kde=True,bins=20)
# Out:
# <AxesSubplot:xlabel='Global_Sales_M$', ylabel='Count'>

# %%
pop=[data['Global_Sales_M$'].mean(),
data['Global_Sales_M$'].median(),
data['Global_Sales_M$'].std()]

# %%
s_10=[s_10['Global_Sales_M$'].mean(),
s_10['Global_Sales_M$'].median(),
s_10['Global_Sales_M$'].std()]

# %%
s_20=[s_20['Global_Sales_M$'].mean(),
s_20['Global_Sales_M$'].median(),
s_20['Global_Sales_M$'].std()]

# %%
s_30=[s_30['Global_Sales_M$'].mean(),
s_30['Global_Sales_M$'].median(),
s_30['Global_Sales_M$'].std()]

# %%
s_40=[s_40['Global_Sales_M$'].mean(),
s_40['Global_Sales_M$'].median(),
s_40['Global_Sales_M$'].std()]

# %%
df=pd.DataFrame()
df['Measures']=['mean','median','std']
df['population']=pop
df['sample_10']=s_10
df['samle_20']=s_20
df['samle_30']=s_30
df['samle_40']=s_40

# %%
df
# Out:
#   Measures  population  sample_10  samle_20  samle_30  samle_40
# 0     mean    0.839803   0.390000  0.965000   0.31500  0.431750
# 1   median    0.170000   0.140000  0.290000   0.09000  0.225000
# 2      std    1.853915   0.476632  1.385266   0.51245  0.650025

# %%
#conclusion:-mean data and median data of sample_20 is highest.
#std data of population is highest.

# %%
data
# Out:
#                                  Game  Year             Genre  \
# 0                  Grand Theft Auto V  2016            Action
# 1           Call of Duty: Black Ops 3  2017           Shooter
# 2               Red Dead Redemption 2  2020  Action-Adventure
# 3                  Call of Duty: WWII  2019           Shooter
# 4                             FIFA 18  2019            Sports
# ..                                ...   ...               ...
# 704               Hyper Light Drifter  2019      Role-Playing
# 705                         Teslagrad  2016          Platform
# 706  Darius Burst: Chronicle Saviours  2019            Action
# 707   The Escapists: The Walking Dead  2018            Action
# 708                    Super Meat Boy  2018          Platform
#
#                Publisher  North_America_Sales_M$  Europe_Sales_M$  \
# 0         Rockstar Games                    6.06             9.71
# 1             Activision                    6.18             6.05
# ...
